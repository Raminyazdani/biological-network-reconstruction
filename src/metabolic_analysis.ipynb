# %% [markdown]
# # Metabolic Network Analysis
# ## Reference Dataset Integration

# %%
import cobra
import pandas as pd
import numpy as np
import glob
# BUG: Missing openpyxl and xlrd imports!

# %%
# Load reference datasets
# This will fail without proper imports!
ref_data_1 = pd.read_excel("data/MSB-14-e7573-s004.xlsx")
ref_data_2 = pd.read_excel("data/msb4100050-s5.xls")
