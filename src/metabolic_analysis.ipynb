# %% [markdown]
# # Metabolic Network Analysis
# ## Initial FBA Implementation

# %%
import cobra
import pandas as pd
import numpy as np

# %%
# Load a single model for testing
# Test with iJO1366 E. coli model

# %%
# Basic FBA
# solution = model.optimize()
# print(solution.objective_value)
