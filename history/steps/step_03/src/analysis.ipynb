# %% [markdown]
# # Metabolic Network Analysis
#
# Initial flux balance analysis for E. coli models

# %%
import cobra
import pandas as pd
import numpy as np

print('COBRApy version:', cobra.__version__)
