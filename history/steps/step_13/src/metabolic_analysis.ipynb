# %% [markdown]
# # Metabolic Network Analysis
# ## Reference Dataset Integration - Fixed

# %%
import cobra
import pandas as pd
import numpy as np
import glob
# FIXED: Added proper imports for Excel handling
import openpyxl  # for .xlsx files
import xlrd      # for .xls files
import odf       # for .ods files

# %%
# Load reference datasets - now works properly
ref_data_1 = pd.read_excel("data/MSB-14-e7573-s004.xlsx")
ref_data_2 = pd.read_excel("data/msb4100050-s5.xls")
print(f"Loaded {len(ref_data_1)} and {len(ref_data_2)} reference entries")
